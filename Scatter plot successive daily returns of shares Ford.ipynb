# %% [markdown]
# ## Install libraries if necessary

# %%
"""Comment out and run cell to install libraries"""
#!pip3 install ipympl
#!pip3 install ipywidgets 
#!pip3 install matplotlib
#!pip3 install numpy 
#!pip3 install pandas_datareader
# Out:
# 'Comment out and run cell to install libraries'

# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader as web
import datetime
import ipympl

# %% [markdown]
# ## Functions to import price data and trading dates

# %%
def read_price_data(stock_symbol, start_date, end_date, interval):
    """Import price data from Yahoo Finance"""
    stock_data = web.get_data_yahoo(stock_symbol, start_date, end_date, interval=interval)
    price_series = stock_data.loc[:, 'Adj Close']
    price_series = price_series.fillna(method='ffill')

    return price_series

# %%
def get_date_list(stock_symbol, start_date, end_date, interval):
    """Generate list of trading dates"""
    stock_data = web.get_data_yahoo(stock_symbol, start_date, end_date, interval=interval)
    date_list = stock_data.index
    
    return date_list

# %% [markdown]
# ## Import stock data

# %%
stock_symbol = 'BKNG' # Stock symbol

# Set time period
start_date = datetime.datetime(2020, 1, 1)
end_date = datetime.datetime(2021, 9, 28)
interval = 'd' # Date interval, by default daily ('d')

# Import price series and list of trading days
try:
    date_list = get_date_list(stock_symbol, start_date, end_date, interval=interval)
    price_series = read_price_data(stock_symbol, start_date, end_date, interval=interval)
except:
    print('Import failed')

# %% [markdown]
# ## Plot price series with annotations

# %%
stock_symbol = 'TSLA' # Stock symbol

# Set time period
start_date = datetime.datetime(2022, 1, 1)
end_date = datetime.datetime(2022, 9, 20)
interval = 'd' # Date interval, by default daily ('d')

# Import price series and list of trading days
try:
    date_list = get_date_list(stock_symbol, start_date, end_date, interval=interval)
    price_series = read_price_data(stock_symbol, start_date, end_date, interval=interval)
except:
    print('Import failed')
    
# Set to '%matplotlib widget' to create interactive plot (default is %matplotlib inline)
# %matplotlib widget

fig, ax = plt.subplots(figsize=(15, 8)) 
#for i in range(len(date_list)):
        #print(i ," ", date_list[i])

"""Manually set your annotations of events here"""
# Annotate events
# Check date_list to match index to event date (for instance, 47  equates March 11, 2020)
# Note that events may occur on non-trading days
ax.annotate('March 15 —  Tesla raises vehicle prices \n dominates Germany’s February EV registrations',
            xy=(date_list[49], price_series[49]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 150),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='right',
            fontsize=8)

ax.annotate('April 2 — Tesla delivers record number of cars despite challenges',
            xy=(date_list[62], price_series[62]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 80),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='left',
            fontsize=8)

ax.annotate('April 20 — Tesla Releases First Quarter 2022 Financial Results',
            xy=(date_list[74], price_series[74]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 110),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='left',
            fontsize=8)


ax.annotate('April 29 - Elon Musk sells millions of Tesla shares',
            xy=(date_list[81], price_series[81]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 50),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='right',
            fontsize=8)

ax.annotate('May 3 - Insight into Teslas production capacity in China',
            xy=(date_list[83], price_series[83]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 80),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='left',
            fontsize=8)

ax.annotate('July 20 — Tesla Releases Second Quarter 2022 Financial Results',
            xy=(date_list[136], price_series[136]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 80),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='right',
            fontsize=8)


ax.annotate('August 5 — Tesla Announces a Three-for-One Stock Split',
            xy=(date_list[148], price_series[148]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 50),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='right',
            fontsize=8)

ax.annotate('August 25 — Three-for-One Stock Split occurs',
            xy=(date_list[162], price_series[162]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 50),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='right',
            fontsize=8)


ax.annotate('September 7 — Model Y Earns 5-Star Safety Rating From Euro NCAP',
            xy=(date_list[170], price_series[170]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 110),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='left',
            fontsize=8)




# Set gridlines
plt.style.use('seaborn-whitegrid')

# Set options for interactive plot
fig.canvas.toolbar_visible = True
fig.canvas.resizable = True

# Set labels
plt.title('Stock price {}'.format(stock_symbol), fontdict = {'fontsize' : 15})
plt.xlabel('Date', fontdict = {'fontsize' : 15})
plt.ylabel('Adj. close price', fontdict = {'fontsize' : 15})

# Plot annotated price series
plt.plot(date_list, price_series)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
